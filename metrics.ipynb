# %%
import pandas as pd
import numpy as np
from os import getcwd
from ast import literal_eval
import matplotlib.pyplot as plt
import igraph as ig
import pprint

# %%
CURR_PATH = getcwd()
# to get the current working directory
PATH_DATA = CURR_PATH + "/data/"

accounts_data = pd.read_csv(PATH_DATA + "instagram_accounts.csv", converters={'id_followers': literal_eval})
posts_data1 = pd.read_csv(PATH_DATA + "instagram_posts.csv")
posts_data2 = pd.read_csv(PATH_DATA + "instagram_posts_1211_1611.csv")
posts_data = pd.concat([posts_data1, posts_data2],axis=0)

# %%
# Checking if our duplicate user changes anything ...
posts_data = posts_data[posts_data['id_user'] != 603282]
posts_data.reset_index(drop=True, inplace=True)

# %%
# Processing posts_data
# posts_data.drop(inplace=True, columns=["Unnamed: 0"])
print(posts_data.head)
posts_data['id_user'].unique().size
# Out:
# <bound method NDFrame.head of       Unnamed: 0  id_user    id_post        date   time half_day  views  \
# 0              0   672702  638779430  09/11/2017  07:53       am      2
# 1              1   474227  953043456  09/11/2017  02:03       am     36
# 2              2   587566  650889385  09/11/2017  02:57       am     59
# 3              3   483543  144265898  09/11/2017  11:43       am     21
# 4              4   394103  955542283  09/11/2017  04:53       pm     16
# ...          ...      ...        ...         ...    ...      ...    ...
# 3040        3042   746387  121744758  16/11/2017  00:57       am    128
# 3041        3043   404047  794339349  16/11/2017  08:49       am    129
# 3042        3044   630873  628294384  16/11/2017  09:59       am     47
# 3043        3045   719594  358445633  16/11/2017  02:46       am    241
# 3044        3046   639300  225756005  16/11/2017  06:54       am      7
#
#       reposts  likes  comments  id_post_origin  link_clicks  donation_tag  \
# 0          18      0         0               0         True         False
# 1          11     16         1               0         True         False
# 2          11      8         1               0         True         False
# 3          14      9         2               0         True         False
# 4           3      2         0       638779430        False         False
# ...       ...    ...       ...             ...          ...           ...
# 3040        0     57         8       217804651        False         False
# 3041        0     38         7       138732663        False         False
# 3042        0     23         0       834132714        False         False
# 3043        0     60        24       909133650        False         False
# 3044        0      3         0       465290461        False         False
#
#       donation_val  house_buy
# 0                0      False
# 1                0      False
# 2                0      False
# 3                0      False
# 4                0      False
# ...            ...        ...
# 3040             0      False
# 3041             0      False
# 3042             0      False
# 3043             0      False
# 3044             0      False
#
# [3045 rows x 15 columns]>
# 3045

# %% [markdown]
# ## _Posts_ Graph Construction
#
# Here we construct the graph for the posts. Each node is identified by its index in the dataframe, and then, its attributes are given as node attributes. All edges are added based on this.
# - Note: this has to be a directed graph to respect  the flow of information i.e. A -> B means that information flows from A to B.

# %%
# Checking for duplicates again
posts_data[posts_data.duplicated(subset=["id_post"])]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, id_user, id_post, date, time, half_day, views, reposts, likes, comments, id_post_origin, link_clicks, donation_tag, donation_val, house_buy]
# Index: []

# %%
## Construct the graph, and add vertices
posts = ig.Graph(directed=True); 
posts.add_vertices(posts_data.index.values)

# %%
for idx in posts_data.index: 
    ### if id_post_origin is zero, append it to its own list
    #   These are the original posts.
    id_origin, id_post, id_user = posts_data.iloc[idx][['id_post_origin', 'id_post','id_user']] 
    # Add the vertex properties first 
    posts.vs[idx]['id_post'] = id_post
    posts.vs[idx]['id_post_origin'] = id_origin
    posts.vs[idx]['id_user'] = id_user    
    
    # Now, if it's not an origin post, 
    # we can add the corresponding edge. 
    if id_origin != 0 :
        # For this, we take the id_origin and 
        # get the index of that post. Then, 
        # we can connect those two nodes :)
        orig_index = posts_data.index[posts_data['id_post'] == id_origin].values[0]
        posts.add_edges([ (orig_index, idx) ])

posts.vs['size']=7
posts.vs['arrow_size']=1
posts.vs['arrow_width']=1
ig.plot(posts)

# %%
# A routine check: 
print("Multiple edges: ", posts.has_multiple())
# Out:
# Multiple edges:  False

# %%
# Finding out the components of our posts-graph
components = posts.clusters(mode='weak')
print(components)

# and getting the users attributed for each.
# Out:
# Clustering with 3045 elements and 4 clusters
# [0] 0, 4, 7, 9, 10, 13, 16, 22, 26, 27, 29, 30, 32, 36, 39, 41, 42, 43, 54,
#     58, 59, 61, 66, 69, 70, 75, 77, 82, 83, 84, 85, 87, 91, 92, 94, 97, 98,
#     100, 101, 104, 106, 107, 109, 110, 111, 113, 122, 124, 128, 134, 135, 137,
#     140, 141, 142, 149, 161, 163, 164, 165, 166, 171, 174, 175, 178, 179, 183,
#     184, 186, 187, 188, 194, 196, 197, 198, 202, 203, 204, 205, 214, 220, 222,
#     224, 225, 227, 229, 231, 234, 236, 237, 241, 242, 246, 247, 250, 251, 252,
#     253, 261, 268, 271, 273, 276, 279, 280, 281, 283, 287, 290, 293, 294, 295,
#     301, 303, 304, 307, 312, 316, 317, 318, 322, 324, 326, 327, 329, 332, 333,
#     334, 336, 338, 340, 341, 343, 349, 353, 366, 368, 371, 372, 376, 378, 388,
#     389, 393, 399, 401, 404, 406, 407, 410, 413, 414, 417, 418, 419, 420, 421,
#     422, 427, 428, 430, 432, 436, 437, 438, 439, 442, 443, 445, 446, 447, 449,
#     450, 454, 456, 461, 465, 466, 467, 471, 483, 485, 490, 491, 496, 499, 504,
#     508, 509, 511, 513, 515, 517, 519, 520, 521, 523, 524, 526, 527, 528, 538,
#     544, 547, 549, 552, 556, 559, 560, 566, 567, 568, 569, 570, 572, 580, 593,
#     595, 602, 608, 610, 613, 614, 616, 623, 625, 629, 631, 632, 635, 637, 639,
#     647, 650, 651, 656, 670, 671, 674, 680, 681, 682, 684, 687, 689, 692, 695,
#     696, 697, 701, 705, 706, 710, 711, 714, 715, 716, 722, 725, 726, 729, 731,
#     737, 741, 742, 745, 751, 758, 765, 767, 769, 770, 771, 774, 784, 786, 788,
#     789, 790, 793, 797, 803, 806, 808, 810, 815, 818, 819, 821, 822, 824, 826,
#     828, 829, 832, 833, 839, 843, 844, 845, 846, 847, 856, 857, 870, 871, 872,
#     873, 879, 881, 884, 886, 887, 888, 889, 892, 893, 896, 897, 898, 900, 902,
#     906, 908, 909, 910, 911, 912, 913, 914, 918, 919, 922, 923, 926, 927, 928,
#     2667, 2669, 2679, 2680, 2690, 2699, 2700, 2707, 2711, 2721, 2723, 2724,
#     2734, 2737, 2742, 2746, 2754, 2755, 2761, 2763, 2765, 2773, 2775, 2780,
#     2783, 2786, 2793, 2795, 2801, 2804, 2815, 2822, 2826, 2831, 2841, 2844,
#     2854, 2855, 2864, 2869, 2872, 2876, 2879, 2889, 2890, 2891, 2898, 2902,
#     2903, 2905, 2911, 2922, 2930, 2939, 2952, 2953, 2960, 2962, 2970, 2985,
#     2987, 2995, 3001, 3004, 3009, 3011, 3015, 3017, 3021, 3026, 3028, 3034,
#     3037

# %% [markdown]
# # Metric 1: Interactivity
#
# Here, we implement the first metric proposed in the first deliverable. This measures the number of likes, clicks, reposts, donations etc. that each post has. We can use this to create a composite ranking, which then provides us a KPI to maximise.

# %%
# We get the nodes representing the original posts 
# i.e. have original post ID = 0.
original_posts = posts.vs(id_post_origin_eq=0)
print('Vertex IDs of the Original Posts: ')
print( original_posts[:]['name'] )
# Out:
# Vertex IDs of the Original Posts:
# [0, 1, 2, 3]

# %% [markdown]
# ### Weak Components
#
# We expect 4 components - one associated to each of the 4 original posts used to seed our userbase. And that's what we get ! Of course, we have weak components because we're working in a Directed Acyclic Graph, so we'll need to ignore the direction of our edges to find components.

# %%
components = dict( zip(original_posts[:]['name'], posts.clusters(mode='weak') ) )
print([len(c) for c in components.values()])
cumulative_interactions = {key : {} for key in original_posts[:]['name']} 
for key in cumulative_interactions:
    cumulative_interactions[key]['like']    = 0
    cumulative_interactions[key]['comment'] = 0
    cumulative_interactions[key]['repost']  = 0
    cumulative_interactions[key]['clicks']  = 0
    cumulative_interactions[key]['donations_tag_count'] = 0
    cumulative_interactions[key]['donations_value']  = 0

# print(cumulative_interactions)
# print(components)
for comp_idx in components:
    for node in components[comp_idx]:
        # print(node)
        row = posts_data.loc[node]

        cumulative_interactions[comp_idx]['like']    += row['likes']#.values[0]
        cumulative_interactions[comp_idx]['comment'] += row['comments']#.values[0]
        cumulative_interactions[comp_idx]['repost']  += row['reposts']#.values[0]
        cumulative_interactions[comp_idx]['clicks']  += row['link_clicks']#.values[0].astype(int)
        cumulative_interactions[key]['donations_tag_count'] += row["donation_tag"]
        cumulative_interactions[key]['donations_value'] += row['donation_val']

pp = pprint.PrettyPrinter(indent=4)
pp.pprint(cumulative_interactions)
# Out:
# [1100, 722, 573, 650]
# {   0: {   'clicks': 109,
#            'comment': 4540,
#            'donations_tag_count': 0,
#            'donations_value': 0,
#            'like': 23950,
#            'repost': 1099},
#     1: {   'clicks': 76,
#            'comment': 3082,
#            'donations_tag_count': 0,
#            'donations_value': 0,
#            'like': 16903,
#            'repost': 723},
#     2: {   'clicks': 61,
#            'comment': 2492,
#            'donations_tag_count': 0,
#            'donations_value': 0,
#            'like': 12835,
#            'repost': 572},
#     3: {   'clicks': 73,
#            'comment': 2594,
#            'donations_tag_count': 31,
#            'donations_value': 755,
#            'like': 14262,
#            'repost': 649}}

# %% [markdown]
# ### Metric 2: Reachability
